# %% [markdown]
# ## Connect MySQL To Python

# %%
import pandas as pd
from sqlalchemy import create_engine
#Conn = mysql.connector.connect(host='localhost',user='root',password='piit2026',database='dup')
Conn = create_engine("mysql+pymysql://root:piit2026@localhost:3306/piit")
Conn
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/piit)

# %%
sheet_id = "1OzAar2RPWjJ9OgvS0h3Fpj7JjsJ2TOijB623-SyM1DU"
gid1 ='1124164429'
gid2 ='1481659858'
url1 = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid1}"
url2 = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid2}"
print(url1, '\n', url1)
# Out:
# https://docs.google.com/spreadsheets/d/1OzAar2RPWjJ9OgvS0h3Fpj7JjsJ2TOijB623-SyM1DU/export?format=csv&gid=1124164429
#  https://docs.google.com/spreadsheets/d/1OzAar2RPWjJ9OgvS0h3Fpj7JjsJ2TOijB623-SyM1DU/export?format=csv&gid=1124164429

# %%
empQ= "select * from emp"
empdf=pd.read_sql(empQ,Conn)
empdf.head()
# Out:
#    empno   ename        job     mgr    hiredate     sal  comm  deptno
# 0   1234  MUNIRA    MANAGER  7839.0  1982-01-23  5000.0   NaN      10
# 1   7369   SMITH      CLERK  7902.0  1980-12-17   800.0   NaN      20
# 2   7788   SCOTT    ANALYST  7566.0  1982-12-09  3000.0   NaN      20
# 3   7839    KING  PRESIDENT     NaN  1981-11-17  5000.0   NaN      10
# 4   7844  TURNER   SALESMAN  7698.0  1981-09-08  1500.0   0.0      30

# %%
deptQ= "select * from dept"
deptdf=pd.read_sql(deptQ,Conn)
deptdf.head()
# Out:
#    deptno       dname       loc
# 0    20.0    RESEARCH    DALLAS
# 1    30.0       SALES   CHICAGO
# 2    40.0  OPERATIONS    BOSTON
# 3    10.0  ACCOUNTING  NEW YORK
# 4    20.0    RESEARCH    DALLAS

# %%
emp_dept=pd.merge(empdf,deptdf,on ='deptno')
emp_dept
# Out:
#     empno   ename        job     mgr    hiredate     sal  comm  deptno  \
# 0    1234  MUNIRA    MANAGER  7839.0  1982-01-23  5000.0   NaN      10
# 1    1234  MUNIRA    MANAGER  7839.0  1982-01-23  5000.0   NaN      10
# 2    7369   SMITH      CLERK  7902.0  1980-12-17   800.0   NaN      20
# 3    7369   SMITH      CLERK  7902.0  1980-12-17   800.0   NaN      20
# 4    7369   SMITH      CLERK  7902.0  1980-12-17   800.0   NaN      20
# 5    7788   SCOTT    ANALYST  7566.0  1982-12-09  3000.0   NaN      20
# 6    7788   SCOTT    ANALYST  7566.0  1982-12-09  3000.0   NaN      20
# 7    7788   SCOTT    ANALYST  7566.0  1982-12-09  3000.0   NaN      20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000.0   NaN      10
# 9    7839    KING  PRESIDENT     NaN  1981-11-17  5000.0   NaN      10
# 10   7844  TURNER   SALESMAN  7698.0  1981-09-08  1500.0   0.0      30
# 11   7844  TURNER   SALESMAN  7698.0  1981-09-08  1500.0   0.0      30
# ...
